# %% [markdown]
# # Ad Predictor
#
# ### Problem definition:
#
# #### Implement a proof-of-concept classifier that uses data about banner ads to predict the advertiser represented in an ad, or return "not an ad" if the image isn't an ad, or return "no prediction" if the classifier isn't sufficiently confident. You can find a labeled dataset with representative class frequencies at http://moatsearch-data.s3.amazonaws.com/homework/ad_classification_hw_dataset.json.
#
# #### Use the following cost matrix to inform your implementation and analysis:
#
# ```
# | predicted   |  correct brand     |  wrong brand  |  non-ad  |  no prediction |
# | actual -----|--------------------|---------------|----------|----------------|
# | any brand   |         0          |      -20      |    -100  |       -5       |
# | non-ad      |         X          |      -40      |     0    |       -5       |
# ```
#
# #### Questions:
# - Discuss the performance of your classifier. For context, include specs for the machine you trained your classifier on.
# - Describe the reasoning behind all major design decisions you had to make.
# - If you were to keep developing this proof-of-concept, what are some changes you think would be promising to explore next, and why?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
givenData = pd.read_json('http://moatsearch-data.s3.amazonaws.com/homework/ad_classification_hw_dataset.json')
givenData.describe()
# Out:
#             label                               md5 ocr_logos ocr_text  \
# count        9729                              9729      9729     9729
# unique       1375                              9729      2407     8056
# top     not_an_ad  6dbd03573e0610e810f13ac1a8170a71        []
# freq         3400                                 1      4710      732
#
#                                            screenshot_url
# count                                                9729
# unique                                               9729
# top     https://search-creatives.s3.amazonaws.com/64/9...
# freq                                                    1

# %%
givenData
# Out:
#                                       label                               md5  \
# 0                          ashley furniture  2bb7ffaef7e7012ade02da88cdf7edf7
# 1                          emirates airline  2eb9ba692c4c687cb3ef8491d042450b
# 2                          verizon wireless  a40a6af8fa229c630c7d4d7951a8f517
# 3                                 walgreens  2a2a280ebc1369ee11be245a630a140a
# 4                           hewlett packard  dd66013a011608d5410eee78517b2082
# 5                                 not_an_ad  6d48faaef070e63092398bd179579cf4
# 6                                  bluehost  d659dc402651c871ad8d631906d93c94
# 7                                 not_an_ad  ce89d5fb1c26cc673b9acbc501d53978
# 8                                 not_an_ad  f5a7ffec70312212ab0c8eb1208f0351
# 9                               fashion mia  cba9c5ca50f1f5be522a0c6b8f4547ab
# 10                               bpi sports  6050c14309216082d58979595dc32de0
# 11                                not_an_ad  9fa0c8b940105d006655cd6fa3300c60
# 12                 fox broadcasting company  5d659c1076df5722b8508814a465f36f
# 13                              fashion mia  9523ac1315b2ea168c5e65b01b1a4c5f
# 14                                not_an_ad  ae963be50266efec09892f8ec0b92c37
# 15                                 bluehost  aa50152a92bad8eef55aa166ad708b7f
# 16                                not_an_ad  c9c6bf9e59d0906c8590751bff2333fd
# 17                    buick gmc dealerships  fe8853b723815df46850397039553dbb
# 18                                 bluehost  a18685df22cfc1b55c614296281c9bfd
# 19                                not_an_ad  13dd62202dd346ffd9eca3d02037981a
# 20                         ashley furniture  66f06e3f832e575960ae08f46dcd3587
# 21                               compassion  23a53d8287287c5f8b49fdf2a2e6077b
# 22                                not_an_ad  fce4ea1a804b37cdf613ca87e50fa131
# 23                                     at&t  d305927818b7cefac431479b3d6e27d0
# 24                               title nine  0ef3d5e832c357c67516a57724a4a922
# 25                                     ford  a72f501c8899faa757c40580427dff00
# 26                              sammy dress  2831a6f0dc53aa56b6c9c820e2d9a807
# 27                                not_an_ad  f66741ee58759fdd1d0655ac5e180f02
# 28                     fidelity investments  06c59231e283e36254312151a3a0e116
# 29    ymca young mens christian association  43b57f1aa8eeabe5b16737bc8e64427e
# ...                                     ...                               ...
# 9699                               bluehost  30c9f005bb2b19937c2a53e7182bb6a9
# 9700                                 amsoil  a4a36aac840c6921807f1d04a594138d
# 9701                              not_an_ad  1200fc2f798306011af1e0e900b19225
# 9702                             jos a bank  da2187bb402baec4aa67a44adb1d1c30
# 9703                              not_an_ad  218c2b69f618439bc926654d49a1d34d
# 9704                           stevens pass  8f4681c469f9df946cd8a8dbe28fd828
# 9705                        lowermybillscom  eefa4f5020b1ef54c977834fcc801e86
# 9706               fox broadcasting company  016e2012f41fbb05921d8b3f6400d52b
# 9707                                  newsy  6b055b8b700c2080654d33c48da0adfd
# 9708                              not_an_ad  12ff1b394ea516246f07cad58b2fc527
# 9709                       emirates airline  3787b34a8e9bf9bc857fca1f05382c5f
# 9710                               bluehost  33f6ee289d944b793c77e6ebea389b04
# 9711                            nhl network  32301325c287dc7d0132626418e6e10a
# 9712                              not_an_ad  40d9602a0b8c2e9785f4794404c8ce3b
# 9713                          neiman marcus  e6a1c35b08a299ee48a9f86b8a68a656
# 9714                 verizon communications  d66e4493b267d70dc1e297e33922f196
# 9715                              not_an_ad  a4566455c926b8f3fb98838eb92e7e0d
# 9716                            fashion mia  89f3867e309070b14bec395a503e05af
# 9717                               t mobile  1860564296bbd44b52fc969ac85b5262
# 9718                              not_an_ad  9ef92ac54c77ec9849d6b43c07cf922b
# 9719                       american express  6b32032477d787f76587c2af893d7035
# 9720                        hewlett packard  bbdaf99c849c2ce7d68592e7024475b6
# 9721                          passport auto  3d802ebf3e473c91bbfa9b45461d5a31
# 9722            lifelock business solutions  65302cb0bfacee70a0d5f33252978b46
# 9723                              not_an_ad  39766b88c99c9b71542991c080c4a886
# 9724                              not_an_ad  20834708f24632b8de0264ba335f550d
# 9725                        lowermybillscom  0e33b5eabf6a2975ab7c5f8ad17b3c37
# 9726                              not_an_ad  b23dbfd756537fcedf9e88abfd3cc1d8
# 9727                              not_an_ad  b148e2e2b9b0fccb69fe17a2ac5dcaf2
# 9728                                walmart  fa5a78da48569586e15b0885c3e17936
#
#                      ocr_logos  \
# 0                           []
# 1                   [Emirates]
# 2           [Verizon Wireless]
# 3                  [Walgreens]
# 4                 [HP Partner]
# 5                           []
# 6                           []
# 7                       [1664]
# 8                           []
# 9                [Fashion MIA]
# 10                [BPI Sports]
# 11                          []
# 12                  [Fox Life]
# 13                          []
# 14                          []
# 15                  [Bluehost]
# 16                          []
# 17                          []
# 18                          []
# 19                 [Amp Japan]
# 20          [Ashley Furniture]
# 21                [Compassion]
# 22                      [ACVB]
# 23                          []
# 24                          []
# 25             [Ford, Buscapé]
# 26                          []
# 27                          []
# 28      [Fidelity Investments]
# 29                      [YMCA]
# ...                        ...
# 9699                [Bluehost]
# 9700                  [Amsoil]
# 9701                        []
# 9702                        []
# 9703            [Apple Market]
# 9704            [Stevens Pass]
# 9705  [Denver Skyline Drawing]
# 9706                [Fox Life]
# 9707                   [Newsy]
# 9708                   [4Flex]
# 9709                [Emirates]
# 9710                        []
# 9711    [2013 NHL Entry Draft]
# 9712               [Pracuj PL]
# 9713           [Neiman Marcus]
# 9714        [Verizon Wireless]
# 9715                        []
# 9716             [Fashion MIA]
# 9717                        []
# 9718                        []
# 9719            [Ticketmaster]
# 9720              [HP Partner]
# 9721                        []
# 9722               [Blue Life]
# 9723            [Adesso Shoes]
# 9724                        []
# 9725                        []
# 9726                        []
# 9727                        []
# 9728                    [2015]
#
#                                                ocr_text  \
# 0     et happy\nASHLEY\nholidays\nthis is home\n25 l...
# 1     Emirates\nBUY 2 TICKETS\nFOR THE\nPRICE OF 1!\...
# 2     Gratis\nVerizon\nLG G Pad'\nTM\n7.0 LTE\nApren...
# 3     Great gifts are right walgreens.\naround the c...
# 4     LA FORCE EST\nPUISSANTE DANS\nNOTRE FAMILLE\nD...
# 5     II We were guided step by step through\nthe pu...
# 6     EASY, HASSLE-FREE\nWEB HOSTING\nFOR $3.95 /MON...
# 7     /004\nKRONEN BOURG\n1664\nPICK UP A\nPACK TODA...
# 8
# 9     Fashion\nMia\nCU U\n$18.95\n$9.95\n$14.95\n$14...
# 10    SPORTS\n100% WHEY\nPROTEIN\nSPORTS\n24s\n5.50\...
# 11    Lopez & Dr. OZ\nReveal $4 Beauty\nTip-Consumer...
# 12                  HAPPY FATHER'S DAY\nfrom\nFOXFALL\n
# 13    Fashion\nUP TO\n90\nOFF\nCO\n2016 Designer\nOU...
# 14        SALE UP\nSELECTED LINES\nOFF\nTO\nSHOP SALE\n
# 15    UNLIMITED\nWEB\nHOSTING\nONLY\n$3.95\nlearn mo...
# 16
# 17    ALL-NEW\n2015 GMC\nTerrain\n$199\nMo. FOR 24 M...
# 18    PROFESSIONAL\nWEB HOSTING\nFOR $3.95 /MONTH\nu...
# 19    ltto's\nMoroccan & Spanish Tapas\nOPEN DAILY, ...
# 20    ASHLEY\nFURNITURE\nHomestore\nbetter\nSanta\n2...
# 21    Compassion\nSPONSORACHILD\nToday's Birthday!\n...
# 22    Discover this land\nlike never before\nEXPLORE...
# 23    Add a line with\nAT&T today!\nGet started\n'Ra...
# 24                   title nine\nFREE 2-DAY\nSHIPPING\n
# 25    Lookout Ford\n2015 Ford\nEscape\nO%\nfor 60 mo...
# 26    SAMMY dress*\nSALE\nBLACK FRIDAY\n$13\nWOMEN'S...
# 27                   ow to Get Essential oils from us\n
# 28        f\nFidelity富達\n按此了解優惠及服務詳情\n捕捉新興市場\n快速增長機遇?\n
# 29    FIND WHAT\nMOVES YOU\nSouthington-Cheshire Com...
# ...                                                 ...
# 9699  UNLIMITED\nWEB\nHOSTING\nONLY\n$3.95\nlearn mo...
# 9700  Protect Your Weekend\nLEARN MORE\nSinthetic\nI...
# 21    https://search-creatives.s3.amazonaws.com/c5/a...
# 22    https://search-creatives.s3.amazonaws.com/0e/a...
# 23    https://moatsearch-data.s3.amazonaws.com/creat...
# 24    https://search-creatives.s3.amazonaws.com/eb/8...
# 25    https://moatsearch-data.s3.amazonaws.com/creat...
# 26    https://search-creatives.s3.amazonaws.com/43/4...
# 27    https://search-creatives.s3.amazonaws.com/2a/b...
# 28    https://moatsearch-data.s3.amazonaws.com/creat...
# 29    https://search-creatives.s3.amazonaws.com/7e/6...
# ...                                                 ...
# 9699  https://search-creatives.s3.amazonaws.com/80/7...
# 9700  https://search-creatives.s3.amazonaws.com/27/d...
# 9701  https://search-creatives.s3.amazonaws.com/ad/4...
# 9702  https://moatsearch-data.s3.amazonaws.com/creat...
# 9703  https://search-creatives.s3.amazonaws.com/92/0...
# 9704  https://search-creatives.s3.amazonaws.com/e1/c...
# 9705  https://moatsearch-data.s3.amazonaws.com/creat...
# 9706  https://search-creatives.s3.amazonaws.com/12/5...
# 9707  https://search-videocreatives.s3.amazonaws.com...
# 9708  https://moatsearch-data.s3.amazonaws.com/creat...
# 9709  https://search-creatives.s3.amazonaws.com/64/a...
# 9710  https://search-creatives.s3.amazonaws.com/13/2...
# 9711  https://search-creatives.s3.amazonaws.com/dd/8...
# 9712  https://search-creatives.s3.amazonaws.com/b2/9...
# 9713  https://search-creatives.s3.amazonaws.com/0f/a...
# 9714  https://search-creatives.s3.amazonaws.com/58/0...
# 9715  https://search-creatives.s3.amazonaws.com/e3/3...
# 9716  https://search-creatives.s3.amazonaws.com/4f/b...
# 9717  https://moatsearch-data.s3.amazonaws.com/creat...
# 9718  https://search-creatives.s3.amazonaws.com/0b/4...
# 9719  https://moatsearch-data.s3.amazonaws.com/creat...
# 9720  https://search-creatives.s3.amazonaws.com/14/5...
# 9721  https://search-creatives.s3.amazonaws.com/62/c...
# 9722  https://moatsearch-data.s3.amazonaws.com/creat...
# 9723  https://search-creatives.s3.amazonaws.com/0a/c...
# 9724  https://search-creatives.s3.amazonaws.com/ff/7...
# 9725  https://moatsearch-data.s3.amazonaws.com/creat...
# 9726  https://search-creatives.s3.amazonaws.com/3e/f...
# 9727  https://moatsearch-data.s3.amazonaws.com/creat...
# 9728  https://search-creatives.s3.amazonaws.com/5f/c...
#
# [9729 rows x 5 columns]

# %%
#clean ocr_text columns and add to new column 'ocr_text_all'
import re
reg = re.compile('\W+')

df = givenData
ocr_text = df['ocr_text'].values

def clean(text):
    return reg.sub(' ', text).strip()

cleanText = [clean(text).lower() for text in ocr_text]
df.insert(loc=0, column='ocr_text_all', value= cleanText) 
df
# Out:
# ---------------------------------------------------------
# ValueError              Traceback (most recent call last)
# <ipython-input-554-dde8c30d6324> in <module>()
#      10
#      11 cleanText = [clean(text).lower() for text in ocr_text]
# ---> 12 df.insert(loc=0, column='ocr_text_all', value= cleanText)
#      13 df
#
# /usr/local/lib/python2.7/site-packages/pandas/core/frame.pyc in insert(self, loc, column, value, allow_duplicates)
#    2447         value = self._sanitize_column(column, value)
#    2448         self._data.insert(loc, column, value,
# -> 2449                           allow_duplicates=allow_duplicates)
#    2450
#    2451     def assign(self, **kwargs):
#
# /usr/local/lib/python2.7/site-packages/pandas/core/internals.pyc in insert(self, loc, item, value, allow_duplicates)
#    3508         if not allow_duplicates and item in self.items:
#    3509             # Should this be a different kind of error??
# -> 3510             raise ValueError('cannot insert %s, already exists' % item)
#    3511
#    3512         if not isinstance(loc, int):
#
# ValueError: cannot insert ocr_text_all, already exists

# %%
#add ocr_logos as well to the 'ocr_text_all'
ocr_logos = df['ocr_logos'].values
ocr_logos

ocr_logos_flattened = [' '.join(s).lower() for s in ocr_logos]

ocr_text_all_new = []
for idx,val in enumerate(ocr_logos_flattened):
    res = val + ' ' + df['ocr_text_all'][idx]
    ocr_text_all_new.append(res)

df['ocr_text_all'] = ocr_text_all_new
df
# Out:
#                                            ocr_text_all  \
# 0      et happy ashley holidays this is home 25 l 36...
# 1     emirates emirates buy 2 tickets for the price ...
# 2     verizon wireless gratis verizon lg g pad tm 7 ...
# 3     walgreens great gifts are right walgreens arou...
# 4     hp partner la force est puissante dans notre f...
# 5      ii we were guided step by step through the pu...
# 6      easy hassle free web hosting for 3 95 month u...
# 7     1664 004 kronen bourg 1664 pick up a pack toda...
# 8
# 9     fashion mia fashion mia cu u 18 95 9 95 14 95 ...
# 10    bpi sports sports 100 whey protein sports 24s ...
# 11     lopez dr oz reveal 4 beauty tip consumers in ...
# 12             fox life happy father s day from foxfall
# 13     fashion up to 90 off co 2016 designer outerwe...
# 14              sale up selected lines off to shop sale
# 15    bluehost unlimited web hosting only 3 95 learn...
# 16
# 17     all new 2015 gmc terrain 199 mo for 24 mos wi...
# 18     professional web hosting for 3 95 month unlim...
# 19    amp japan ltto s moroccan spanish tapas open d...
# 20    ashley furniture ashley furniture homestore be...
# 21    compassion compassion sponsorachild today s bi...
# 22    acvb discover this land like never before expl...
# 23     add a line with at t today get started raq s ...
# 24                       title nine free 2 day shipping
# 25    ford buscapé lookout ford 2015 ford escape o f...
# 26     sammy dress sale black friday 13 women s butt...
# 27                     ow to get essential oils from us
# 28                      fidelity investments f fidelity
# 29    ymca find what moves you southington cheshire ...
# ...                                                 ...
# 9699  bluehost unlimited web hosting only 3 95 learn...
# 9700  amsoil protect your weekend learn more sinthet...
# 9701   don t buy gold in 2016 before you buy learn h...
# 9702   psal bank your choice sale shirts sweaters ti...
# 9703  apple market eabrooke i view your weekly ad sp...
# 9704  stevens pass you miss 100 of the lines you don...
# 9705  denver skyline drawing parents do this before ...
# 9706                 fox life fok new girl tue 9 8c fox
# 9707                                        newsy newsy
# 9708  4flex baili wick express just the money you ne...
# 9709  emirates emirates book 2 passengers traveling ...
# 9710   easy hassle free web hosting for 3 95 month u...
# 9711  2013 nhl entry draft nhl gamecenter live 2015 ...
# 9712  pracuj pl what ails your practice keep your pr...
# 9713  neiman marcus neima maucua free shipping free ...
# 9714  verizon wireless manage your fleet verizon fro...
# 9715                                                 pu
# 9716  fashion mia fashion top magic price 13 95 magi...
# 9717   magenta mobil l mit top handy monatlicher gru...
# 9706               fox broadcasting company  016e2012f41fbb05921d8b3f6400d52b
# 9707                                  newsy  6b055b8b700c2080654d33c48da0adfd
# 9708                              not_an_ad  12ff1b394ea516246f07cad58b2fc527
# 9709                       emirates airline  3787b34a8e9bf9bc857fca1f05382c5f
# 9710                               bluehost  33f6ee289d944b793c77e6ebea389b04
# 9711                            nhl network  32301325c287dc7d0132626418e6e10a
# 9712                              not_an_ad  40d9602a0b8c2e9785f4794404c8ce3b
# 9713                          neiman marcus  e6a1c35b08a299ee48a9f86b8a68a656
# 9714                 verizon communications  d66e4493b267d70dc1e297e33922f196
# 9715                              not_an_ad  a4566455c926b8f3fb98838eb92e7e0d
# 9716                            fashion mia  89f3867e309070b14bec395a503e05af
# 9717                               t mobile  1860564296bbd44b52fc969ac85b5262
# 9718                              not_an_ad  9ef92ac54c77ec9849d6b43c07cf922b
# 9719                       american express  6b32032477d787f76587c2af893d7035
# 9720                        hewlett packard  bbdaf99c849c2ce7d68592e7024475b6
# 9721                          passport auto  3d802ebf3e473c91bbfa9b45461d5a31
# 9722            lifelock business solutions  65302cb0bfacee70a0d5f33252978b46
# 9723                              not_an_ad  39766b88c99c9b71542991c080c4a886
# 9724                              not_an_ad  20834708f24632b8de0264ba335f550d
# 9725                        lowermybillscom  0e33b5eabf6a2975ab7c5f8ad17b3c37
# 9726                              not_an_ad  b23dbfd756537fcedf9e88abfd3cc1d8
# 9727                              not_an_ad  b148e2e2b9b0fccb69fe17a2ac5dcaf2
# 9728                                walmart  fa5a78da48569586e15b0885c3e17936
#
#                      ocr_logos  \
# 0                           []
# 1                   [Emirates]
# 2           [Verizon Wireless]
# 3                  [Walgreens]
# 4                 [HP Partner]
# 5                           []
# 6                           []
# 7                       [1664]
# 8                           []
# 9                [Fashion MIA]
# 10                [BPI Sports]
# 11                          []
# 12                  [Fox Life]
# 13                          []
# 14                          []
# 15                  [Bluehost]
# 16                          []
# 17                          []
# 18                          []
# 19                 [Amp Japan]
# 20          [Ashley Furniture]
# 21                [Compassion]
# 22                      [ACVB]
# 23                          []
# 24                          []
# 25             [Ford, Buscapé]
# 26                          []
# 27                          []
# 28      [Fidelity Investments]
# 29                      [YMCA]
# ...                        ...
# 9699                [Bluehost]
# 9700                  [Amsoil]
# 9701                        []
# 9702                        []
# 9703            [Apple Market]
# 9704            [Stevens Pass]
# 9705  [Denver Skyline Drawing]
# 9706                [Fox Life]
# 9707                   [Newsy]
# 9708                   [4Flex]
# 9709                [Emirates]
# 9710                        []
# 9711    [2013 NHL Entry Draft]
# 9712               [Pracuj PL]
# 9713           [Neiman Marcus]
# 9714        [Verizon Wireless]
# 9715                        []
# 9716             [Fashion MIA]
# 9717                        []
# 9718                        []
# 9719            [Ticketmaster]
# 9720              [HP Partner]
# 9721                        []
# 9722               [Blue Life]
# 9723            [Adesso Shoes]
# 9724                        []
# 9725                        []
# 9726                        []
# 9727                        []
# 9728                    [2015]
#
#                                                ocr_text  \
# 0     et happy\nASHLEY\nholidays\nthis is home\n25 l...
# 9704  https://search-creatives.s3.amazonaws.com/e1/c...
# 9705  https://moatsearch-data.s3.amazonaws.com/creat...
# 9706  https://search-creatives.s3.amazonaws.com/12/5...
# 9707  https://search-videocreatives.s3.amazonaws.com...
# 9708  https://moatsearch-data.s3.amazonaws.com/creat...
# 9709  https://search-creatives.s3.amazonaws.com/64/a...
# 9710  https://search-creatives.s3.amazonaws.com/13/2...
# 9711  https://search-creatives.s3.amazonaws.com/dd/8...
# 9712  https://search-creatives.s3.amazonaws.com/b2/9...
# 9713  https://search-creatives.s3.amazonaws.com/0f/a...
# 9714  https://search-creatives.s3.amazonaws.com/58/0...
# 9715  https://search-creatives.s3.amazonaws.com/e3/3...
# 9716  https://search-creatives.s3.amazonaws.com/4f/b...
# 9717  https://moatsearch-data.s3.amazonaws.com/creat...
# 9718  https://search-creatives.s3.amazonaws.com/0b/4...
# 9719  https://moatsearch-data.s3.amazonaws.com/creat...
# 9720  https://search-creatives.s3.amazonaws.com/14/5...
# 9721  https://search-creatives.s3.amazonaws.com/62/c...
# 9722  https://moatsearch-data.s3.amazonaws.com/creat...
# 9723  https://search-creatives.s3.amazonaws.com/0a/c...
# 9724  https://search-creatives.s3.amazonaws.com/ff/7...
# 9725  https://moatsearch-data.s3.amazonaws.com/creat...
# 9726  https://search-creatives.s3.amazonaws.com/3e/f...
# 9727  https://moatsearch-data.s3.amazonaws.com/creat...
# 9728  https://search-creatives.s3.amazonaws.com/5f/c...
#
# [9729 rows x 6 columns]

# %%
#Randomize dataset
df_randomized = df
df_randomized = df_randomized.reindex(np.random.permutation(df_randomized.index))

# %%
#Choose a smaller subset of ad labels
labels = df_randomized['label'].values
labelsList = list(labels)
adLabels = set()

#TODO: Keeping this to 500 labels in order to execute this code in finite time
for l in labels:
    if (len(adLabels)<500):
        adLabels.add(l)
adLabels
# Out:
# {u'69 wfmz',
#  u'aaa insurance',
#  u'aaa travel',
#  u'aarons',
#  u'aarp',
#  u'abercrombie fitch',
#  u'academy sports outdoors',
#  u'adda52com',
#  u'adobe',
#  u'adonit',
#  u'adt',
#  u'air canada',
#  u'aktion deutschland hilft',
#  u'alaska airlines',
#  u'aldi',
#  u'alhambra theatre dining',
#  u'alibabacom',
#  u'alice and olivia',
#  u'align',
#  u'allianz',
#  u'allied electronics',
#  u'allsaints',
#  u'aloft hotels',
#  u'amazon',
#  u'american college of education',
#  u'american express',
#  u'american home',
#  u'ansi',
#  u'apollo',
#  u'app store',
#  u'apple music',
#  u'argos',
#  u'art van furniture',
#  u'ashley furniture',
#  u'at&t',
#  u'aveda',
#  u'aventine',
#  u'avigilon',
#  u'aviva',
#  u'axiom financial strategies group',
#  u'b beyond diet',
#  u'babbel',
#  u'babiesrus',
#  u'babybel',
#  u'babyshop',
#  u'backblaze',
#  u'baers furniture design',
#  u'baller arcade',
#  u'banggoodcom',
#  u'barberitos',
#  u'baylor',
#  u'beatport',
#  u'befrugalcom',
#  u'bein sports',
#  u'belhaven university',
#  u'bella cosmeticsnet',
#  u'belterra park gaming entertainment center',
#  u'best buy',
#  u'billiard factory',
#  u'bing',
#  u'biolife',
#  u'bistro md',
#  u'bloomberg',
#  u'blue cross blue shield',
#  u'blue vine',
#  u'bluefly',
#  u'bluehost',
#  u'bmc',
#  u'bon appetit',
#  u'bose',
#  u'brandsmart usa',
#  u'bravo',
#  u'brooks brothers',
#  u'buick gmc dealerships',
#  u'cafe heavenly',
#  u'cala homes',
#  u'calprofen',
#  u'cancer treatment centers of america',
#  u'carpet one',
#  u'castlight health',
#  u'caterpillar cat',
#  u'central michigan university',
#  u'centurylink',
#  u'charles schwab',
#  u'chicago theatre week',
#  u'chicos',
#  u'chinawatch',
#  u'chumash casino resort',
#  u'cincinnati symphony orchestra',
#  u'clarks',
#  u'claro',
#  u'classesusa',
#  u'cleanmymac 3',
#  u'cleveland clinic',
#  u'club sport',
#  u'coast',
#  u'coldwell banker',
#  u'colgate',
#  u'college board',
#  u'collette',
#  u'comcast business',
#  u'compare stores',
#  u'compassion',
#  u'conedison solutions',
#  u'connect for health colorado',
#  u'corcoran real estate',
#  u'cornerstone',
#  u'cosme decom',
#  u'crye leike realtors',
#  u'daily burn',
#  u'dash albert',
#  u'deal hunter',
#  u'debenhams',
#  u'deer valley resort',
#  u'dell',
#  u'depend',
#  u'desert botanical garden',
#  u'digi key',
#  u'dk',
#  u'dorignacs food center',
#  u'dot bo',
#  u'dream hotels',
#  u'duproprio',
#  u'dyson',
#  u'east carolina university',
#  u'edureka',
#  u'elle',
#  u'elsevier',
#  u'emirates airline',
#  u'engie',
#  u'eppendorf',
#  u'eset',
#  u'esri',
#  u'eureka pizza',
#  u'expedia',
#  u'explore minnesota',
#  u'fab fit fun',
#  u'fashion mia',
#  u'feliway',
#  u'fidelity investments',
#  u'fifth third bank',
#  u'fifty shades of grey',
#  u'flir',
#  u'fluke',
#  u'fly racing',
#  u'food lion',
#  u'ford',
#  u'fox broadcasting company',
#  u'fox sports',
#  u'fuel',
#  u'fuji',
#  u'g2acom',
#  u'gaggenau',
#  u'gamekit',
#  u'gap',
#  u'gearbest',
#  u'geico',
#  u'general electric',
#  u'global',
#  u'global golf',
#  u'godrej properties',
#  u'golds gym',
#  u'goodwin college',
#  u'graton resort casino',
#  u'guide dogs',
#  u'gun lake casino',
#  u'gus',
#  u'guthrie theater',
#  u'harrys',
#  u'hawaii state federal credit union',
#  u'health data management',
#  u'health net',
#  u'hewlett packard',
#  u'hide my ass',
#  u'hiredcom',
#  u'hmr weight management',
#  u'hms bikes',
#  u'home decorators collection',
#  u'homeland stores',
#  u'horchow',
#  u'houston grand opera',
#  u'houzz',
#  u'howard alan events ltd',
#  u'hyatt regency',
#  u'ibm',
#  u'icici bank',
#  u'igs energy',
#  u'imd',
#  u'inc research',
#  u'indiana convention center',
#  u'indigo',
#  u'industry west',
#  u'ingles',
#  u'inside out movie',
#  u'intel',
#  u'international spy museum',
#  u'iphone 6',
#  u'itunes',
#  u'itunes radio',
#  u'j jill',
#  u'jackson hole',
#  u'jacob javits center',
#  u'jelly belly',
#  u'jimmy jazz',
#  u'jos a bank',
#  u'jublia',
#  u'jupiter merlin income portfolio',
#  u'justin bieber',
#  u'kb home',
#  u'kbis',
#  u'keiser university',
#  u'kiehls',
#  u'knobbe martens',
#  u'know roaming',
#  u'kroger',
#  u'la mer',
#  u'la roche posay',
#  u'la z boy',
#  u'labtech',
#  u'ladbrokes',
#  u'larabar',
#  u'lazada',
#  u'lear capital',
#  u'learnsmart',
#  u'lease advisors',
#  u'lendingtree',
#  u'lenovo',
#  u'lifecell',
#  u'lifelock business solutions',
#  u'lightspeed',
#  u'lithium',
#  u'live nation',
#  u'lloyds bank',
#  u'lombardo homes',
#  u'london stansted airport',
#  u'love and mercy movie',
#  u'lowermybillscom',
#  u'lowes foods',
#  u'm&t bank',
#  u'mackinac island',
#  u'macmillan cancer support',
#  u'macys',
#  u'mafa online gaming',
#  u'makemechiccom',
#  u'mantecatrailercom',
#  u'marin general hospital',
#  u'marriott hotels',
#  u'martech',
#  u'martinez manglardi attorneys',
#  u'mcafee',
#  u'mcdonalds',
#  u'mcgraw hill education',
#  u'mecum auctions',
#  u'media temple',
#  u'meerkat movies',
#  u'mega millions',
#  u'melia',
#  u'melijoecom',
#  u'mgm grand detroit',
#  u'mgm resorts international',
#  u'miami',
#  u'microsoft',
#  u'microsoft office 365',
#  u'miller theatre',
#  u'minecraft games',
#  u'mission tortillas',
#  u'mitsubishi',
#  u'mitsubishi electric',
#  u'mobilescouk',
#  u'mongo db world',
#  u'monster jam',
#  u'mr holmes movie',
#  u'mr rooter',
#  u'mybannermakercom',
#  u'myrtle beach',
#  u'nanawall',
#  u'napleton',
#  u'nationwide insurance',
#  u'nch software',
#  u'neiman marcus',
#  u'netcredit',
#  u'netwrix',
#  u'neu',
#  u'newegg',
#  u'newsy',
#  u'next advisor',
#  u'nordstrom',
#  u'not_an_ad',
#  u'nucific',
#  u'nwoa newton wellesley orthopedic associates',
#  u'nysc',
#  u'oakley',
#  u'omron',
#  u'ontario canada',
#  u'open english',
#  u'optimum',
#  u'orange county pacific symphony',
#  u'oregon convention center',
#  u'orpheum theatre',
#  u'otto',
#  u'pace',
#  u'palm beach research group',
#  u'palmetto dental arts',
#  u'pantene',
#  u'papa johns pizza',
#  u'paramount theatre',
#  u'park meadows senior living',
#  u'passport auto',
#  u'patricias',
#  u'paul gauguin cruises',
#  u'peachtree',
#  u'pedigree',
#  u'penfed credit union',
#  u'pfaltzgraff',
#  u'pierre money mart',
#  u'planet calypso',
#  u'planet fitness',
#  u'plantronics',
#  u'platos closet',
#  u'pofcom',
#  u'polaris',
#  u'pologeorgis',
#  u'popeyes',
#  u'porter',
#  u'price chopper',
#  u'pricesteals',
#  u'procter gamble',
#  u'prodeticz',
#  u'progressive',
#  u'prudential',
#  u'psc gym',
#  u'publix',
#  u'puffs',
#  u'pure barre',
#  u'pure gym',
#  u'pwc',
#  u'qardio arm',
#  u'ragnar',
#  u'ragnar trail',
#  u'ragtime musical',
#  u'rcn',
#  u'reach',
#  u'realdose nutrition',
#  u'realtree',
#  u'red bull',
#  u'refinery29',
#  u'regis university',
#  u'remax',
#  u'renault',
#  u'renault twingo',
#  u'retailmenot',
#  u'reverbnation',
#  u'rich dad education',
#  u'rocket mortgage',
#  u'romwe',
#  u'rooms to go',
#  u'rosetta stone',
#  u'roto rooter',
#  u'routeperfect',
#  u'royal caribbean cruise',
#  u'rsm',
#  u'ryerson university',
#  u'sadhguru',
#  u'sage',
#  u'saks fifth avenue',
#  u'sammy dress',
#  u'samsung',
#  u'san felipe casino',
#  u'sanebox',
#  u'sap',
#  u'sas analytics',
#  u'seasonic',
#  u'seattle university',
#  u'sensus',
#  u'serta',
#  u'seven springs',
#  u'shein sheinside',
#  u'shell',
#  u'shen yun performing arts',
#  u'shopathomecom',
#  u'shoppers supply',
#  u'shopperstop',
#  u'skyscanner',
#  u'slumberworld',
#  u'smarthomepricecom',
#  u'solarwinds',
#  u'sonic',
#  u'sothebys international realty',
#  u'sound money defense league',
#  u'south beach diet',
#  u'sparta war of empires game',
#  u'specs howard school of media arts',
#  u'spring arbor university',
#  u'staples',
#  u'starprices',
#  u'state bicycle co',
#  u'state farm',
#  u'steves plumbing inc',
#  u'stylewe',
#  u'subway',
#  u'sun basket',
#  u'sun rv resorts',
#  u'sundara inn spa',
#  u'sunrise',
#  u'suzuki',
#  u'swanson health products',
#  u'swissquote',
#  u't mobile',
#  u'table mountain casino',
#  u'tachi palace hotel casino',
#  u'tahoe south',
#  u'tamron',
#  u'target',
#  u'tchibo',
#  u'telestream',
#  u'tesoro',
#  u'texas instruments',
#  u'texture',
#  u'the 5 wave book',
#  u'the chicago school of professional psychology',
#  u'the dayton art institute',
#  u'the golden apple award',
#  u'the great courses',
#  u'the home depot',
#  u'the lion king',
#  u'the revenant movie',
#  u'the tech museum',
#  u'the telegraph',
#  u'thermacare',
#  u'ticketmaster',
#  u'tidebuy',
#  u'time warner cable',
#  u'time warner cable business class',
#  u'title nine',
#  u'tog 24',
#  u'total war arena game',
#  u'toyota',
#  u'tracfone',
#  u'transport for london',
#  u'troy university',
#  u'tumbledeal',
#  u'turningstonecom',
#  u'u by kotex',
#  u'uber',
#  u'umass amherst',
#  u'unibet',
#  u'university of california berkeley',
#  u'university of greenwich',
#  u'university of hartford',
#  u'university of phoenix',
#  u'urban fitness',
#  u'utah jazz nba',
#  u'varidesk',
#  u'vend',
#  u'verbena',
#  u'verizon communications',
#  u'verizon wireless',
#  u'vermont tech',
#  u'versionone',
#  u'vibram',
#  u'vip',
#  u'virgin',
#  u'virgin atlantic',
#  u'visions federal credit union',
#  u'visitfloridacom',
#  u'vitamix',
#  u'viva towels',
#  u'vmturbo',
#  u'vmware',
#  u'vodafone',
#  u'voices',
#  u'vonage',
#  u'vormetric',
#  u'walgreens',
#  u'walmart',
#  u'walt disney world',
#  u'washington wedding experience',
#  u'waterville valley resort',
#  u'wayfair',
#  u'wellness',
#  u'william hill',
#  u'window world',
#  u'winecom',
#  u'wistia',
#  u'wolters kluwer',
#  u'wordpress',
#  u'xero',
#  u'xerox',
#  u'xfinity',
#  u'xojet',
#  u'yahoo search',
#  u'yepmecom',
#  u'ymca young mens christian association',
#  u'yoplait',
#  u'yupp tv',
#  u'zap',
#  u'zenni optical',
#  u'zerorez',
#  u'zobha',
#  u'zulily'}

# %%
adLabelsList = list(adLabels)

# %%
#Select only subset of df containing adLabels
df_filtered = df_randomized.loc[df_randomized['label'].isin(adLabelsList)]

# %%
#Keep 60% training set, 20% validation set, 20% test set
# test set -> to be removed. This set would be used to calculate final performance of the classifier
# validation set -> Should be used for selecting model (I will try out between NBMultinomial, Logistic and linear svm).
# I will select the model which performs best in my cross-validation test results

splitAt = int(0.2 * len(df_filtered))

test = df_filtered[0:splitAt]
cv_trainTest = df_filtered[splitAt:]
# cv_test = cv_trainTest[0:splitAt]
# cv_train = cv_trainTest[splitAt:]

# %%
#model selection
from sklearn.cross_validation import KFold
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import SGDClassifier
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn import svm

#NOTE: I would have ideally wanted to do parameter tuning using GridSearch to select the best parameters. Skipping it in the interest of time
#NOTE 2: I would have liked to add a misclassification cost for the label 'not_an_ad' in the objective. As I have not implemented this before, I will be skipping it in the interest of time.
clf1 = MultinomialNB()
clf2 = SGDClassifier(loss='log', penalty='l2', alpha=1e-3, n_iter=5, random_state=10)   #logistic regression
clf3 = SGDClassifier(loss='hinge', penalty='l2', alpha=1e-3, n_iter=5, random_state=10) #linear svm
clf4 = svm.SVC(C=1.0, decision_function_shape='ovr', degree = 4, gamma = 1.0) #non-linear svm
clfs = [clf1, clf2, clf3, clf4]
#Adding this to normalize feature vector 
tfidf_transformer = TfidfTransformer()
vectorizer = CountVectorizer()

Y = cv_trainTest['label'].values
kf = KFold(len(Y), n_folds=5)

max = 0
scores = []

for idx in range(0,len(clfs)):
    #implement cross-validation
    cv_scores = []
    for train_index, test_index in kf:
        X_train_counts = vectorizer.fit_transform(cv_trainTest['ocr_text_all'].values[train_index])
        X_train = tfidf_transformer.fit_transform(X_train_counts)
        X_test_counts = vectorizer.transform(cv_trainTest['ocr_text_all'].values[test_index])
        X_test = tfidf_transformer.transform(X_test_counts)
        Y_train, Y_test = Y[train_index], Y[test_index]
        clf = clfs[idx].fit(X_train, Y_train)
        score = clf.score(X_test, Y_test)
        cv_scores.append(score)
    scores.append(np.mean(cv_scores))
    
print(scores)
highScoreIndex = np.argmax(scores)
print(highScoreIndex)
clf = clfs[highScoreIndex]
# Out:
# [0.61388690050107375, 0.63922691481746596, 0.82763063707945594, 0.84853256979241232]
# 3

# %%
#create dictionary for ocr_text_all using vectorizer

#Use training+validation set to train the model
X_train_counts = vectorizer.fit_transform(cv_trainTest['ocr_text_all'].values)
X_train = tfidf_transformer.fit_transform(X_train_counts)
Y_train = cv_trainTest['label']

#use test set to get performance now
X_test_counts = vectorizer.transform(test['ocr_text_all'].values)
X_test = tfidf_transformer.transform(X_test_counts)
Y_test = test['label'].values

# %%
#get performance on test set

model = clf.fit(X_train, Y_train)
predictedRaw = model.predict(X_test)
model.score(X_test, Y_test)
# Out:
# 0.77147766323024058

# %%
from sklearn import metrics

# transport for london       0.00      0.00      0.00         1
#  tumbledeal       0.00      0.00      0.00         1
#        uber       0.00      0.00      0.00         1
#      unibet       1.00      0.88      0.93         8
# university of california berkeley       0.00      0.00      0.00         1
# university of hartford       0.00      0.00      0.00         1
# utah jazz nba       0.00      0.00      0.00         1
#    varidesk       0.00      0.00      0.00         1
#        vend       0.00      0.00      0.00         1
#     verbena       0.00      0.00      0.00         1
# verizon communications       0.64      0.70      0.67        10
# verizon wireless       0.60      0.38      0.46         8
# vermont tech       0.00      0.00      0.00         1
#         vip       0.00      0.00      0.00         1
#      virgin       0.00      0.00      0.00         1
# viva towels       0.00      0.00      0.00         1
#     vmturbo       0.00      0.00      0.00         1
#    vodafone       0.00      0.00      0.00         1
#      voices       0.00      0.00      0.00         1
#      vonage       0.00      0.00      0.00         1
#   vormetric       0.00      0.00      0.00         1
#   walgreens       1.00      0.80      0.89        15
#     walmart       1.00      0.89      0.94        27
# walt disney world       0.00      0.00      0.00         1
#     wayfair       0.00      0.00      0.00         1
# william hill       1.00      0.67      0.80         3
# window world       0.00      0.00      0.00         1
#      wistia       0.00      0.00      0.00         1
# wolters kluwer       0.00      0.00      0.00         1
#        xero       0.00      0.00      0.00         1
#       xerox       0.00      0.00      0.00         1
#     xfinity       1.00      0.50      0.67         2
# yahoo search       1.00      0.50      0.67         6
#    yepmecom       0.00      0.00      0.00         1
# ymca young mens christian association       1.00      0.83      0.91         6
#     yupp tv       1.00      1.00      1.00         1
#         zap       0.00      0.00      0.00         1
#     zerorez       0.00      0.00      0.00         1
#      zulily       1.00      1.00      1.00        13
#
# avg / total       0.69      0.77      0.71      1746

# %%
#Sampleprediction: #model.predict(vectorizer.transform(['This is a Verizon ad'])) => Verizon wireless

#return no prediction for weak predictions
def predictedModified(model, x):
    predictions = []
    for elem in x:
        maxBoundary = np.max(model.decision_function(elem))
        #based on cost matrix- place higher penalty for predicting not_an_ad 
        prediction = model.predict(elem)
        if (maxBoundary< 1.0):
            prediction = np.array([u'no prediction'])
            #increase maxBoundary constraint to remove wrong no_ad predictions on any_brand
        elif(prediction == u'not_an_ad' and maxBoundary < 2.0):
            prediction = np.array([u'no prediction'])    
        predictions.append(prediction[0])
    return predictions
     
# predictedModified(model, vectorizer.transform(['This is a Verizon ad', 'This is walgreens']))    
predictions = predictedModified(model, X_test)

# %%
#Get generic performance
from sklearn import metrics

#performance report
print(metrics.classification_report(Y_test, predictions))

#Confusion matrix
print(metrics.confusion_matrix(Y_test, predictions))

# %%
#Get performance figures on the test Set which highlight how well we did as per the cost-matrix:

#A. Total number of records in test set

#B. any_brand metrics:
    #a. %age
    #b. %correctly predicted
    #c. %incorrectly predicted as not_an_ad // Need to ensure this is lowest
    #d. %incorrectly predicted as wrong band //moderate cost
    #e. %surrendered //low cost
    
    
#C. not_an_ad metrics:
    #a. %age
    #b. %correctly predicted
    #c. %incorrectly predicted as wrong band //moderate-high cost
    #d. %surrendered //low cost 
    

#anyBrandCount + noAdCount = totalCount
#a. %age composition
totalCount = len(Y_test)
anyBrandCount = len([k for k in Y_test if k!='not_an_ad' and k!= 'no prediction'])
anyBrandCountPerc = float(anyBrandCount)/totalCount
noAdCount = len([k for k in Y_test if k=='not_an_ad'])
noAdCountPerc = float(noAdCount)/totalCount

#number of surrenders by the classifier
noPredictionCount = len([k for k in predictions if k=='no prediction'])
noPredictionCountPerc = float(noPredictionCount)/totalCount

# %correctly Predicted, %incorrectlyredicted, %surrendered
anyBrandCorrect = 0
not_an_adCorrect = 0
not_an_adSurrender = 0
anyBrandSurrender = 0
not_an_adIncorrect = 0
anyBrand_notAnAdIncorrect = 0
anyBrand_wrongBrandIncorrect = 0

for idx,k in enumerate(Y_test):
    if(k == predictions[idx]):
        if (k=='not_an_ad'):
            not_an_adCorrect += 1    
        else:
            anyBrandCorrect += 1
    elif(predictions[idx] == 'no prediction'):
        if (k=='not_an_ad'):
            not_an_adSurrender += 1
        else:
            anyBrandSurrender += 1
    else:
        if (k=='not_an_ad'):
            not_an_adIncorrect += 1
        else:
            if (predictions[idx] == 'not_an_ad'):
                anyBrand_notAnAdIncorrect += 1
            else:
                anyBrand_wrongBrandIncorrect += 1

# %%
#from tabulate import tabulate
from prettytable import PrettyTable

print('~Performance Stats~:')
print('Total records: ', totalCount)

t = PrettyTable(['Category', 'total(%)', 'Correct', 'Incorrect_wrongAd', 'Incorrect_not_an_ad', 'No Prediction'])
t.add_row(['AnyBrand', anyBrandCountPerc, anyBrandCorrect, anyBrand_wrongBrandIncorrect, anyBrand_notAnAdIncorrect, anyBrandSurrender])
t.add_row(['No_ad', noAdCountPerc, not_an_adCorrect, not_an_adIncorrect, 'X', not_an_adSurrender])
print t

# %% [markdown]
# # Implementations Details:
#
# On analyzing the dataset, it appeared to me that 'ocr_logos' and 'ocr_text' seemed to be the key insight providers for what the label output was.
#
# These are the steps I took to create the classifier for predicting the ad label:
#
# 1. Cleaned text inside ocr_text field by converting each to lowercase and replacing any whitespaces with a single
#    space. Also, concatenated the cleaned ocr_logos with this.
#
# 2. Randomized dataset and chose 500 labels from output labels
#
# 3. Filtered the Randomized dataset to contain only the selected labels; created a 60-20-20 split.
#
# 4. Did cross-validation on train set and validation set to select a model (went with SVM using RBF kernel)
#
# 5. Re-trained on train+validation set; Measured performance on the test set.
#
# 6. Got performance stats specifically to measure cost incurred based on cost-matrix
#
#
# Things that I would have liked to work on:
#
# 1. Title casing: Currently I convert all text to lowercase, which loses information that could potentially pinpoint
#    occurence of an Adword label in ocr_text.
# 2. Lemmatization & punctuation trimming: Would have wanted to use this on the ocr_text. Would have definitely improved
#    performance.
# 3. grid-search: Grid search to find the most optimal parameters for the model.
# 4. Learning curves: Would have liked to plot a learning curve on my hypothesis, comparing the cross-validation
#    training and test sets to inform me if my model has high variance or high bias. Based on this, I could proceed to
#    use more data points in training if model has high variance.
# 5. Embedding Label cost in the hypothesis: Currently, the predictions are modified based on the distance from the
#    decision boundary (the assumption here is that svm is selected from the models). It would be much better to add
#    weights to the parameter which penalize heavilt
